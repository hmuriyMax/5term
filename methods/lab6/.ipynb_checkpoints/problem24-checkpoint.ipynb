# %% [markdown]
# ## **РЗ 24**

# %% [markdown]
# ![image.png](attachment:bbbf6e7a-485c-4530-9bdc-58f29b170812.png)

# %% [markdown]
# ![image.png](attachment:556ce559-2387-4529-86dc-c299b1821e26.png)

# %% [markdown]
# #### **Решение методом Эйлера**

# %% [markdown]
# Метод Эйлера:
# $$y_i = y_{i-1} + hf(t_{i-1}, y_{i-1})$$
# Нам дано:
# $$t_0 = 1, y_0 = 0, f = \frac{y}{t + 1} + t + 1$$
# Тогда:
# $$y_1 = y_0 + hf(t_0, y_0) = 0 + 0.2*f(1, 0) = 0.4$$
# $$y_2 = y_1 + hf(t_1, y_1) = 0.4 + 0.2*f(1.2, 0.4) = 2.381818$$
# $$y_3 = y_2 + hf(t_2, y_2) = 2.381818 + 0.2*f(1.4, 2.381818) = $$
