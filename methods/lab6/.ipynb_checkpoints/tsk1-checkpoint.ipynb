# %%
import main

# %%
x = [1950, 1960, 1970, 1980, 1990, 2000, 2010, 2020]
y = [7.2, 7.7, 8.2, 8.3, 8.8, 8.9, 9.4, 10.4]

# %%
res = list()
funcs = list()
for i in range(1, 6):
    tmp = main.min_sqs_met(i, x, y)
    funcs.append(tmp)
    res.append(tmp(2019))
print(res)
# Out:
# [9.968452380952376, 10.099910714285713, 10.248660714285695, 10.26322165178569, 10.255434077884273]

# %%
delta = [10.313447 - el for el in res]
print(delta)
# Out:
# [0.34499461904762363, 0.2135362857142873, 0.06478628571430534, 0.05022534821431002, 0.058012922115727505]

# %%
func = main.lagrange_met(x, y)

# %%
print(func(2019))
# Out:
# 10.526150850625

# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
x = main.np.linspace(min(x), max(x), 1000)
plt.title('Сравнение методов')
plt.xlabel('x')
plt.ylabel('y (mlns)')
plt.plot(x, func(x), label='lagrange')
i = 0
for func in funcs:
    i+=1
    plt.plot(x, func(x), label='MHK '+str(i))
plt.grid()
plt.legend()
